# %%
import pandas as pd
import os

# %%
pd.options.display.max_columns = None

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/Master/Desktop/Adalab/project-da-promo-d-module-2-team-2-/notebooks'

# %%
df_kaggle = pd.read_csv("../datos/data_remaning_kaggle.csv")

# %%
df_kaggle.head(None)
#eliminamos las partes de la cuestión 38, ya que pertenece a las Cuestiones suplementarias y estas están dirigidas a un público no especializado (estudiantes y no profesionales)
# Out:
#        Unnamed: 0  index                                         Q18_Part_1  \
# 0               0      0  General purpose image/video tools (PIL, cv2, s...
# 1               1      1                                                NaN
# 2               2      2                                                NaN
# 3               3      3  General purpose image/video tools (PIL, cv2, s...
# 4               4      4                                                NaN
# ...           ...    ...                                                ...
# 25968       25968  25968  General purpose image/video tools (PIL, cv2, s...
# 25969       25969  25969                                                NaN
# 25970       25970  25970                                                NaN
# 25971       25971  25971                                                NaN
# 25972       25972  25972                                                NaN
#
# ...

# %%
df_kaggle.isnull().sum()
# Out:
# Unnamed: 0           0
# index                0
# Q18_Part_1       23311
# Q18_Part_2       23233
# Q18_Part_3       23257
#                  ...
# Q38_B_Part_8     24953
# Q38_B_Part_9     25307
# Q38_B_Part_10    23226
# Q38_B_Part_11    21431
# Q38_B_OTHER      25596
# Length: 214, dtype: int64

# %%
df_kaggle.columns
#son tipo de preguntas select all that apply/multirespuesta
# Out:
# Index(['Unnamed: 0', 'index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=214)

# %%
for elemento in df_kaggle.columns:
    if "38" in elemento:
        df_kaggle.drop([elemento],axis = 1, inplace = True)
df_kaggle.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1',
#        ...
#        'Q36_B_Part_7', 'Q36_B_OTHER', 'Q37_B_Part_1', 'Q37_B_Part_2',
#        'Q37_B_Part_3', 'Q37_B_Part_4', 'Q37_B_Part_5', 'Q37_B_Part_6',
#        'Q37_B_Part_7', 'Q37_B_OTHER'],
#       dtype='object', length=190)

# %%
# función para eliminar las columnas en las que no nos vamos a centrar en el estudio
def eliminar (dataframe, *num_columna):
    for elemento in dataframe.columns:
        for i  in num_columna:
            if i in elemento:
                dataframe.drop([elemento],axis = 1, inplace = True)
    return dataframe.columns

# %%
#HEMOS BORRADO LOS ELEMENTOS QUE APARECEN EN LA LISTA DE *ARGS, QUE HEMOS CONSIDERADO QUE NO VAMOS A UTILIZAR EN NUESTRO ANÁLISIS
eliminar(df_kaggle,*['27_B', '29_B', '30_B', '31_B', '32_B', '34_B', '36_B', '37_B', '38_B'])
# Out:
# Index(['Unnamed: 0', 'index', 'Q18_Part_1', 'Q18_Part_2', 'Q18_Part_3',
#        'Q18_Part_4', 'Q18_Part_5', 'Q18_Part_6', 'Q18_OTHER', 'Q19_Part_1',
#        ...
#        'Q42_Part_3', 'Q42_Part_4', 'Q42_Part_5', 'Q42_Part_6', 'Q42_Part_7',
#        'Q42_Part_8', 'Q42_Part_9', 'Q42_Part_10', 'Q42_Part_11', 'Q42_OTHER'],
#       dtype='object', length=101)

# %%
df_kaggle.head(None)
# Out:
#        Unnamed: 0  index                                         Q18_Part_1  \
# 0               0      0  General purpose image/video tools (PIL, cv2, s...
# 1               1      1                                                NaN
# 2               2      2                                                NaN
# 3               3      3  General purpose image/video tools (PIL, cv2, s...
# 4               4      4                                                NaN
# ...           ...    ...                                                ...
# 25968       25968  25968  General purpose image/video tools (PIL, cv2, s...
# 25969       25969  25969                                                NaN
# 25970       25970  25970                                                NaN
# 25971       25971  25971                                                NaN
# 25972       25972  25972                                                NaN
#
# ...

# %%
df_exported_data = pd.read_csv("../datos/exported_db_data.csv")

# %%
df_exported_data.head()
# Out:
#    index         Q10_Part_1       Q10_Part_2 Q10_Part_3 Q10_Part_4 Q10_Part_5  \
# 0      0                NaN  Colab Notebooks        NaN        NaN        NaN
# 1      1   Kaggle Notebooks  Colab Notebooks        NaN        NaN        NaN
# 2      2   Kaggle Notebooks              NaN        NaN        NaN        NaN
# 3      3                NaN  Colab Notebooks        NaN        NaN        NaN
# 4      4                NaN              NaN        NaN        NaN        NaN
#
#   Q10_Part_6 Q10_Part_7 Q10_Part_8 Q10_Part_9 Q10_Part_10  \
# 0        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN         NaN
#
#             Q10_Part_11 Q10_Part_12 Q10_Part_13 Q10_Part_14 Q10_Part_15  \
# ...

# %%
for i in df_exported_data.columns:
    print(i)
#LAS HERRAMIENTAS DE NOTEBOOKS
# Out:
# index
# Q10_Part_1
# Q10_Part_2
# Q10_Part_3
# Q10_Part_4
# Q10_Part_5
# Q10_Part_6
# Q10_Part_7
# Q10_Part_8
# Q10_Part_9
# Q10_Part_10
# Q10_Part_11
# Q10_Part_12
# Q10_Part_13
# Q10_Part_14
# Q10_Part_15
# Q10_Part_16
# Q10_OTHER

# %%
df_data_txt = pd.read_csv("../datos/data_txt_clean.txt", sep = ";")

# %%
df_data_txt.head(2)
# Out:
#    index         Q3                 Q4                       Q5          Q6  \
# 0      0      India  Bachelor’s degree                    Other  5-10 years
# 1      1  Indonesia    Master’s degree  Program/Project Manager   20+ years
#
#        Q8                                                Q11        Q13  \
# 0  Python                                           A laptop  2-5 times
# 1  Python  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#           Q15                        Q20                   Q21  Q22  \
# 0  5-10 years  Manufacturing/Fabrication      50-249 employees  3-4
# 1    < 1 year  Manufacturing/Fabrication  1000-9,999 employees  1-2
#
#                                                  Q23            Q25  \
# 0                      No (we do not use ML methods)  25,000-29,999
# 1  We are exploring ML methods (and may one day p...  60,000-69,999
#
#          Q26  Q33  Q35                                                Q41  \
# ...

# %%
for i in df_data_txt.columns:
    print(i)
#COMMENT: hay que ver cuáles sirven y cuáles no
# Out:
# index
# Q3
# Q4
# Q5
# Q6
# Q8
# Q11
# Q13
# Q15
# Q20
# Q21
# Q22
# Q23
# Q25
# Q26
# Q33
# Q35
# Q41
# Q7
# Q9
# Q12
# Q14
# Q16
# Q17
# Q24
# Q32
# Q34

# %%
df_posicion = df_data_txt[(df_data_txt ["Q5"] == "Business Analyst") | (df_data_txt ["Q5"] == "Data Analyst")]

# %%
df_posicion.head()
# Out:
#     index                        Q3  \
# 16     16                   Belgium
# 32     32  United States of America
# 33     33                     Egypt
# 46     46                     China
# 52     52              South Africa
#
#                                                    Q4            Q5  \
# 16                                  Bachelor’s degree  Data Analyst
# 32  Some college/university study without earning ...  Data Analyst
# 33                                  Bachelor’s degree  Data Analyst
# 46  Some college/university study without earning ...  Data Analyst
# 52                                    Master’s degree  Data Analyst
#
#            Q6      Q8                            Q11        Q13  \
# 16  20+ years  Python                       A laptop      Never
# 32  < 1 years       R  A personal computer / desktop      Never
# 33  3-5 years       R                       A laptop      Never
# 46  < 1 years  Python  A personal computer / desktop  2-5 times
# ...

# %%
df_posicion["Q8"].value_counts()/df_posicion.shape[0]*100
# Out:
# Python        67.145916
# SQL           10.676048
# R              8.045274
# C++            1.193025
# Java           0.917712
# C              0.764760
# Other          0.734169
# MATLAB         0.611808
# Julia          0.428266
# None           0.428266
# Javascript     0.397675
# Bash           0.183542
# Swift          0.030590
# Name: Q8, dtype: float64

# %%
#data_value_count = df_posicion[df_posicion["Q24"].value_counts()/df_posicion.shape[0]*100]
#combinaciones posibles seleccionadas
#ver los datos en los values y ver cuánta gente ha respondido a unos u otros

# %%
def df_explore(dataframe, nombre):
    print(f"EXPLORACIÓN DEL DATAFRAME {nombre.upper()}")
    print("--------------")
    print(f"El dataframe {nombre} tiene {dataframe.shape[0]} filas y {dataframe.shape[1]} columnas")
    print("--------------")
    print("Las primeras 5 columnas son:")
    display(dataframe.head())
    print("Las últimas 5 columnas son:")
    display(dataframe.tail())
    print("--------------")
    print("Una muestra de dos filas seleccionadas al azar:")
    display(dataframe.sample(2))
    print("--------------")
    print(f"El dataframe {nombre} tiene las siguientes columnas:")
    for col in dataframe.columns:
        print(col) 
    print("--------------")
    print(f"Los principales estadísticos de las variables numéricas son:")
    display(dataframe.describe())
    print("--------------")
    print(f"Los principales estadísticos de las variables categóricas son:")
    display(dataframe.describe(include=object))
    print("--------------")
    print("El porcentaje de nulos por columna:")
    for i, col in enumerate(dataframe.isnull().sum()):
        print(f"{dataframe.isnull().sum().index[i]}: {col/dataframe.shape[0]*100}")
    print("--------------")
    print("El numero de valores distintos de cada columna es:")
    for col in dataframe.columns:
        if len(dataframe[col].value_counts()) > 6:
            print(col, len(dataframe[col].value_counts()))
        else:
            print(col, len(dataframe[col].value_counts()))
            print(f"Los valores son: {dataframe[col].unique()}")

# %%
df_explore(df_posicion, "Job Title: Data Analyst and Business Analyst")
# Out:
# EXPLORACIÓN DEL DATAFRAME JOB TITLE: DATA ANALYST AND BUSINESS ANALYST
# --------------
# El dataframe Job Title: Data Analyst and Business Analyst tiene 3269 filas y 27 columnas
# --------------
# Las primeras 5 columnas son:
#     index                        Q3  \
# 16     16                   Belgium
# 32     32  United States of America
# 33     33                     Egypt
# 46     46                     China
# 52     52              South Africa
#
#                                                    Q4            Q5  \
# 16                                  Bachelor’s degree  Data Analyst
# 32  Some college/university study without earning ...  Data Analyst
# 33                                  Bachelor’s degree  Data Analyst
# 46  Some college/university study without earning ...  Data Analyst
# 52                                    Master’s degree  Data Analyst
#
#            Q6      Q8                            Q11        Q13  \
# ...

# %%
df_exp = df_data_txt[(df_data_txt ["Q6"] == "Business Analyst") | (df_data_txt ["Q6"] == "Data Analyst")]

# %%
df_data_xml = pd.read_xml("../datos/data_xml_clean.xml")

# %%
df_data_xml.head()
# Out:
#    level_0  index  time    age gender
# 0        0      0   910  50-54    Man
# 1        1      1   784  50-54    Man
# 2        2      2   924  22-24    Man
# 3        3      3   575  45-49    Man
# 4        4      4   781  45-49    Man

# %%
for i in df_data_xml.columns:
    print(i)
#COMMENT: edad y género podemos mantenerlas como columnas
# Out:
# level_0
# index
# time
# age
# gender
